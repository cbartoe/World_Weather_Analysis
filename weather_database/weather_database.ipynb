# %%
#import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np 
from datetime import datetime
from config import weather_api_key
from citipy import citipy
import requests

#create the url
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=" + weather_api_key

# %%
#create a set of random latitudes and longitudes as a combination.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
#add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
# create a list for holding the cities
cities = []

#identify the nearest city for each latitude and longitude combo. 
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    #if the city is unique then we will add it to the cities list
    if city not in cities:
        cities.append(city)
#print the city count 
len(cities)
# Out:
# 729

# %%
#create an empty list to hold the weather data. 
city_data = []

#print the beginning of the logging. 
print("Beginning Data Retrieval   ")
print("---------------------------")

#create counters
record_count = 1
set_count = 1

#loop through the cities in out list
for i, city in enumerate(cities):

    #group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count +=1
        record_count =1
    #create endpoint URL with each city 
    city_url = url + "&q=" + city.replace(" ","+")

    #log the URS, record, and set the numbers and the city. 
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    #add 1 to the record_count 
    record_count +=1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_current = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": city_current})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        continue

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# ---------------------------
# Processing Record 1 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 2 of Set 1 | poum
# Processing Record 3 of Set 1 | thompson
# Processing Record 4 of Set 1 | ilulissat
# Processing Record 5 of Set 1 | dikson
# Processing Record 6 of Set 1 | berdigestyakh
# Processing Record 7 of Set 1 | hurghada
# Processing Record 8 of Set 1 | kaitangata
# Processing Record 9 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 10 of Set 1 | punta arenas
# Processing Record 11 of Set 1 | nome
# Processing Record 12 of Set 1 | mataura
# Processing Record 13 of Set 1 | hobart
# Processing Record 14 of Set 1 | port elizabeth
# Processing Record 15 of Set 1 | puerto ayora
# Processing Record 16 of Set 1 | yar-sale
# Processing Record 17 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 18 of Set 1 | vaini
# Processing Record 19 of Set 1 | ushuaia
# Processing Record 20 of Set 1 | biltine
# Processing Record 21 of Set 1 | batuan
# Processing Record 22 of Set 1 | rikitea
# Processing Record 23 of Set 1 | bluff
# Processing Record 24 of Set 1 | nikolskoye
# Processing Record 25 of Set 1 | leningradskiy
# Processing Record 26 of Set 1 | bredasdorp
# Processing Record 27 of Set 1 | sao joao da barra
# Processing Record 28 of Set 1 | grand centre
# City not found. Skipping...
# Processing Record 29 of Set 1 | barrow
# Processing Record 30 of Set 1 | hilo
# Processing Record 31 of Set 1 | provideniya
# Processing Record 32 of Set 1 | ariogala
# Processing Record 33 of Set 1 | banda aceh
# Processing Record 34 of Set 1 | kodiak
# Processing Record 35 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 36 of Set 1 | chokurdakh
# Processing Record 37 of Set 1 | alofi
# Processing Record 38 of Set 1 | hermanus
# Processing Record 39 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 40 of Set 1 | ribeira grande
# Processing Record 41 of Set 1 | alsfeld
# Processing Record 42 of Set 1 | karaul
# City not found. Skipping...
# Processing Record 43 of Set 1 | iqaluit
# Processing Record 44 of Set 1 | avarua
# Processing Record 45 of Set 1 | saldanha
# Processing Record 46 of Set 1 | takoradi
# Processing Record 47 of Set 1 | cherskiy
# Processing Record 48 of Set 1 | coromandel
# Processing Record 49 of Set 1 | busselton
# Processing Record 50 of Set 1 | esperance
# Processing Record 1 of Set 2 | yellowknife
# Processing Record 2 of Set 2 | tres arroyos
# Processing Record 3 of Set 2 | chihuahua
# Processing Record 4 of Set 2 | victoria
# Processing Record 5 of Set 2 | galesong
# Processing Record 6 of Set 2 | arraial do cabo
# Processing Record 7 of Set 2 | saint-philippe
# Processing Record 8 of Set 2 | hamilton
# Processing Record 9 of Set 2 | sakakah
# Processing Record 10 of Set 2 | vao
# Processing Record 11 of Set 2 | liverpool
# Processing Record 12 of Set 2 | nhulunbuy
# Processing Record 13 of Set 2 | tasiilaq
# Processing Record 14 of Set 2 | jamestown
# Processing Record 15 of Set 2 | qaanaaq
# Processing Record 16 of Set 2 | tuatapere
# Processing Record 17 of Set 2 | nanortalik
# Processing Record 18 of Set 2 | dubbo
# Processing Record 19 of Set 2 | east london
# Processing Record 20 of Set 2 | katobu
# Processing Record 21 of Set 2 | hirado
# Processing Record 22 of Set 2 | butaritari
# Processing Record 23 of Set 2 | morros
# Processing Record 24 of Set 2 | hithadhoo
# Processing Record 25 of Set 2 | dawlatabad
# Processing Record 26 of Set 2 | ponta do sol
# Processing Record 27 of Set 2 | la ronge
# Processing Record 28 of Set 2 | rolim de moura
# City not found. Skipping...
# Processing Record 29 of Set 2 | shache
# Processing Record 30 of Set 2 | tiksi
# Processing Record 31 of Set 2 | cuenca
# Processing Record 32 of Set 2 | tuktoyaktuk
# Processing Record 33 of Set 2 | turayf
# Processing Record 34 of Set 2 | sataua
# City not found. Skipping...
# Processing Record 35 of Set 2 | bethel
# Processing Record 36 of Set 2 | choix
# Processing Record 37 of Set 2 | mastic beach
# Processing Record 38 of Set 2 | college
# Processing Record 39 of Set 2 | itarema
# Processing Record 40 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 41 of Set 2 | porkhov
# Processing Record 42 of Set 2 | longyearbyen
# Processing Record 43 of Set 2 | benguela
# Processing Record 44 of Set 2 | cape town
# Processing Record 45 of Set 2 | trat
# Processing Record 46 of Set 2 | napoleon
# Processing Record 47 of Set 2 | geraldton
# Processing Record 48 of Set 2 | atuona
# Processing Record 49 of Set 2 | nalut
# Processing Record 50 of Set 2 | te anau
# Processing Record 1 of Set 3 | isangel
# Processing Record 2 of Set 3 | cabo san lucas
# Processing Record 3 of Set 3 | upernavik
# Processing Record 4 of Set 3 | veraval
# Processing Record 5 of Set 3 | taoudenni
# Processing Record 6 of Set 3 | okato
# Processing Record 7 of Set 3 | puerto colombia
# Processing Record 8 of Set 3 | sanarate
# Processing Record 9 of Set 3 | souillac
# Processing Record 10 of Set 3 | tecoanapa
# Processing Record 11 of Set 3 | elizabeth city
# Processing Record 12 of Set 3 | bambous virieux
# Processing Record 13 of Set 3 | pringsewu
# Processing Record 14 of Set 3 | benghazi
# Processing Record 15 of Set 3 | neuquen
# Processing Record 16 of Set 3 | valparaiso
# Processing Record 17 of Set 3 | bay roberts
# Processing Record 18 of Set 3 | anadyr
# Processing Record 19 of Set 3 | faanui
# Processing Record 20 of Set 3 | naze
# Processing Record 21 of Set 3 | muros
# Processing Record 22 of Set 3 | kapaa
# Processing Record 23 of Set 3 | morant bay
# Processing Record 24 of Set 3 | afmadu
# City not found. Skipping...
# Processing Record 25 of Set 3 | rocha
# Processing Record 26 of Set 3 | bocana de paiwas
# Processing Record 27 of Set 3 | buloh kasap
# Processing Record 28 of Set 3 | divnomorskoye
# Processing Record 29 of Set 3 | verkhnyaya inta
# Processing Record 30 of Set 3 | muhos
# Processing Record 31 of Set 3 | lata
# Processing Record 32 of Set 3 | batemans bay
# Processing Record 33 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 34 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 35 of Set 3 | puerto el triunfo
# Processing Record 36 of Set 3 | new norfolk
# Processing Record 37 of Set 3 | sussex
# Processing Record 38 of Set 3 | dronninglund
# Processing Record 39 of Set 3 | carnarvon
# Processing Record 40 of Set 3 | turukhansk
# Processing Record 41 of Set 3 | kharp
# Processing Record 42 of Set 3 | guerrero negro
# Processing Record 43 of Set 3 | faya
# Processing Record 44 of Set 3 | muravlenko
# Processing Record 45 of Set 3 | hayato
# City not found. Skipping...
# Processing Record 46 of Set 3 | cidreira
# Processing Record 47 of Set 3 | bonavista
# Processing Record 48 of Set 3 | pevek
# Processing Record 49 of Set 3 | cayenne
# Processing Record 50 of Set 3 | meulaboh
# Processing Record 1 of Set 4 | nishihara
# Processing Record 2 of Set 4 | clyde river
# Processing Record 3 of Set 4 | hambantota
# Processing Record 4 of Set 4 | cervo
# Processing Record 5 of Set 4 | alihe
# Processing Record 6 of Set 4 | port alfred
# Processing Record 7 of Set 4 | mount pleasant
# Processing Record 8 of Set 4 | vardo
# Processing Record 9 of Set 4 | kathmandu
# Processing Record 10 of Set 4 | bathsheba
# Processing Record 11 of Set 4 | berlevag
# Processing Record 12 of Set 4 | manokwari
# Processing Record 13 of Set 4 | san patricio
# Processing Record 14 of Set 4 | hasaki
# Processing Record 15 of Set 4 | saint-joseph
# Processing Record 16 of Set 4 | albany
# Processing Record 17 of Set 4 | bur gabo
# City not found. Skipping...
# Processing Record 18 of Set 4 | lompoc
# Processing Record 19 of Set 4 | ternate
# Processing Record 20 of Set 4 | qaqortoq
# Processing Record 21 of Set 4 | toguchin
# Processing Record 22 of Set 4 | srednekolymsk
# Processing Record 23 of Set 4 | williams lake
# Processing Record 24 of Set 4 | acarau
# Processing Record 25 of Set 4 | les cayes
# Processing Record 26 of Set 4 | sao jose da coroa grande
# Processing Record 27 of Set 4 | carballo
# Processing Record 28 of Set 4 | dingle
# Processing Record 29 of Set 4 | biak
# Processing Record 30 of Set 4 | narsaq
# Processing Record 31 of Set 4 | lubao
# Processing Record 32 of Set 4 | sambava
# Processing Record 33 of Set 4 | pisco
# Processing Record 34 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 35 of Set 4 | cobh
# Processing Record 36 of Set 4 | escanaba
# Processing Record 37 of Set 4 | labuan
# Processing Record 38 of Set 4 | marsa matruh
# Processing Record 39 of Set 4 | udachnyy
# Processing Record 40 of Set 4 | denpasar
# Processing Record 41 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 42 of Set 4 | lafiagi
# Processing Record 43 of Set 4 | vostok
# Processing Record 44 of Set 4 | mananjary
# Processing Record 45 of Set 4 | juneau
# Processing Record 46 of Set 4 | beaumont
# Processing Record 47 of Set 4 | bengkulu
# Processing Record 48 of Set 4 | de-kastri
# Processing Record 49 of Set 4 | loughrea
# Processing Record 50 of Set 4 | aquidauana
# Processing Record 1 of Set 5 | ahuimanu
# Processing Record 2 of Set 5 | riohacha
# Processing Record 3 of Set 5 | ryazhsk
# Processing Record 4 of Set 5 | meadow lake
# Processing Record 5 of Set 5 | makakilo city
# Processing Record 6 of Set 5 | yazoo city
# Processing Record 7 of Set 5 | ahipara
# Processing Record 8 of Set 5 | auch
# Processing Record 9 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 10 of Set 5 | acapulco
# Processing Record 11 of Set 5 | sabang
# Processing Record 12 of Set 5 | castro
# Processing Record 13 of Set 5 | xining
# Processing Record 14 of Set 5 | beinamar
# Processing Record 15 of Set 5 | georgetown
# Processing Record 16 of Set 5 | leh
# Processing Record 17 of Set 5 | rabo de peixe
# Processing Record 18 of Set 5 | saskylakh
# Processing Record 19 of Set 5 | coihaique
# Processing Record 20 of Set 5 | bhola
# Processing Record 21 of Set 5 | ubinskoye
# Processing Record 22 of Set 5 | champerico
# Processing Record 23 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 24 of Set 5 | synya
# Processing Record 25 of Set 5 | airai
# Processing Record 26 of Set 5 | ambulu
# Processing Record 27 of Set 5 | nuevo progreso
# Processing Record 28 of Set 5 | kinsale
# Processing Record 29 of Set 5 | tommot
# Processing Record 30 of Set 5 | klaksvik
# Processing Record 31 of Set 5 | morgan city
# Processing Record 32 of Set 5 | jibuti
# Processing Record 33 of Set 5 | najran
# Processing Record 34 of Set 5 | greenwood
# Processing Record 35 of Set 5 | shushtar
# Processing Record 36 of Set 5 | asfi
# Processing Record 37 of Set 5 | hofn
# Processing Record 38 of Set 5 | buala
# Processing Record 39 of Set 5 | clovis
# Processing Record 40 of Set 5 | solok
# Processing Record 41 of Set 5 | deputatskiy
# Processing Record 42 of Set 5 | chase
# Processing Record 43 of Set 5 | sitka
# Processing Record 44 of Set 5 | staicele
# Processing Record 45 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 46 of Set 5 | challans
# Processing Record 47 of Set 5 | tlahualilo
# City not found. Skipping...
# Processing Record 48 of Set 5 | san antonio
# Processing Record 49 of Set 5 | norman wells
# Processing Record 50 of Set 5 | grindavik
# Processing Record 1 of Set 6 | kavieng
# Processing Record 2 of Set 6 | san quintin
# Processing Record 3 of Set 6 | ovalle
# Processing Record 4 of Set 6 | gizo
# Processing Record 5 of Set 6 | maniitsoq
# Processing Record 6 of Set 6 | floriano
# Processing Record 7 of Set 6 | jardim
# Processing Record 8 of Set 6 | lieksa
# Processing Record 9 of Set 6 | fortuna
# Processing Record 10 of Set 6 | pacific grove
# Processing Record 11 of Set 6 | chuy
# Processing Record 12 of Set 6 | lavrentiya
# Processing Record 13 of Set 6 | campbell river
# Processing Record 14 of Set 6 | daru
# Processing Record 15 of Set 6 | nicoya
# Processing Record 16 of Set 6 | verkh-chebula
# Processing Record 17 of Set 6 | severo-kurilsk
# Processing Record 18 of Set 6 | wajima
# Processing Record 19 of Set 6 | khatanga
# Processing Record 20 of Set 6 | ketchikan
# Processing Record 21 of Set 6 | hobyo
# Processing Record 22 of Set 6 | nokaneng
# Processing Record 23 of Set 6 | hirara
# Processing Record 24 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 25 of Set 6 | shiloh
# Processing Record 26 of Set 6 | chagda
# City not found. Skipping...
# Processing Record 27 of Set 6 | lebu
# Processing Record 28 of Set 6 | santa fe
# Processing Record 29 of Set 6 | ucluelet
# Processing Record 30 of Set 6 | plettenberg bay
# Processing Record 31 of Set 6 | darhan
# Processing Record 32 of Set 6 | aras
# Processing Record 33 of Set 6 | broken hill
# Processing Record 34 of Set 6 | shahpur
# Processing Record 35 of Set 6 | ostrovnoy
# Processing Record 36 of Set 6 | gaoyou
# Processing Record 37 of Set 6 | ustka
# Processing Record 38 of Set 6 | mandal
# Processing Record 39 of Set 6 | richards bay
# Processing Record 40 of Set 6 | mahebourg
# Processing Record 41 of Set 6 | leonding
# Processing Record 42 of Set 6 | mar del plata
# Processing Record 43 of Set 6 | zhangye
# Processing Record 44 of Set 6 | fort nelson
# Processing Record 45 of Set 6 | glebychevo
# Processing Record 46 of Set 6 | belyy yar
# Processing Record 47 of Set 6 | porto novo
# Processing Record 48 of Set 6 | iquitos
# Processing Record 49 of Set 6 | vilyuysk
# Processing Record 50 of Set 6 | halifax
# Processing Record 1 of Set 7 | luderitz
# Processing Record 2 of Set 7 | podporozhye
# Processing Record 3 of Set 7 | orbetello
# Processing Record 4 of Set 7 | monywa
# Processing Record 5 of Set 7 | avera
# Processing Record 6 of Set 7 | kandrian
# Processing Record 7 of Set 7 | dzhusaly
# City not found. Skipping...
# Processing Record 8 of Set 7 | mehamn
# Processing Record 9 of Set 7 | port macquarie
# Processing Record 10 of Set 7 | palmer
# Processing Record 11 of Set 7 | athabasca
# Processing Record 12 of Set 7 | sens
# Processing Record 13 of Set 7 | huarmey
# Processing Record 14 of Set 7 | caravelas
# Processing Record 15 of Set 7 | lagoa
# Processing Record 16 of Set 7 | moberly
# Processing Record 17 of Set 7 | hailar
# Processing Record 18 of Set 7 | matagami
# Processing Record 19 of Set 7 | namibe
# Processing Record 20 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 21 of Set 7 | awjilah
# Processing Record 22 of Set 7 | calvinia
# Processing Record 23 of Set 7 | omoa
# Processing Record 24 of Set 7 | camocim
# Processing Record 25 of Set 7 | beyneu
# Processing Record 26 of Set 7 | karkaralinsk
# City not found. Skipping...
# Processing Record 27 of Set 7 | southbridge
# Processing Record 28 of Set 7 | utiroa
# City not found. Skipping...
# Processing Record 29 of Set 7 | rawson
# Processing Record 30 of Set 7 | neiafu
# Processing Record 31 of Set 7 | dicabisagan
# Processing Record 32 of Set 7 | salalah
# Processing Record 33 of Set 7 | moron
# Processing Record 34 of Set 7 | barra do garcas
# Processing Record 35 of Set 7 | praia da vitoria
# Processing Record 36 of Set 7 | gardan diwal
# City not found. Skipping...
# Processing Record 37 of Set 7 | kampot
# Processing Record 38 of Set 7 | severodvinsk
# Processing Record 39 of Set 7 | banjar
# Processing Record 40 of Set 7 | zhangjiakou
# Processing Record 41 of Set 7 | kpandu
# Processing Record 42 of Set 7 | manggar
# Processing Record 43 of Set 7 | kati
# Processing Record 44 of Set 7 | lamar
# Processing Record 45 of Set 7 | ust-tsilma
# Processing Record 46 of Set 7 | bonthe
# Processing Record 47 of Set 7 | kangasala
# Processing Record 48 of Set 7 | chapais
# Processing Record 49 of Set 7 | padang
# Processing Record 50 of Set 7 | torbay
# Processing Record 1 of Set 8 | qianguo
# Processing Record 2 of Set 8 | bereda
# Processing Record 3 of Set 8 | northam
# Processing Record 4 of Set 8 | port lincoln
# Processing Record 5 of Set 8 | quatre cocos
# Processing Record 6 of Set 8 | paamiut
# Processing Record 7 of Set 8 | kloulklubed
# Processing Record 8 of Set 8 | novocheremshansk
# Processing Record 9 of Set 8 | aklavik
# Processing Record 10 of Set 8 | port hardy
# Processing Record 11 of Set 8 | sandnessjoen
# Processing Record 12 of Set 8 | manono
# Processing Record 13 of Set 8 | am timan
# Processing Record 14 of Set 8 | alibag
# Processing Record 15 of Set 8 | suditi
# Processing Record 16 of Set 8 | valle de allende
# Processing Record 17 of Set 8 | hong gai
# Processing Record 18 of Set 8 | budogoshch
# Processing Record 19 of Set 8 | darnah
# Processing Record 20 of Set 8 | gordeyevka
# Processing Record 21 of Set 8 | alvaraes
# Processing Record 22 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 23 of Set 8 | kirakira
# Processing Record 24 of Set 8 | kaoma
# Processing Record 25 of Set 8 | sirjan
# Processing Record 26 of Set 8 | hervey bay
# Processing Record 27 of Set 8 | solton
# Processing Record 28 of Set 8 | riyadh
# Processing Record 29 of Set 8 | beringovskiy
# Processing Record 30 of Set 8 | calbuco
# Processing Record 31 of Set 8 | kenda
# Processing Record 32 of Set 8 | alot
# Processing Record 33 of Set 8 | lapeer
# Processing Record 34 of Set 8 | longside
# City not found. Skipping...
# Processing Record 35 of Set 8 | jalu
# Processing Record 36 of Set 8 | knyaze-volkonskoye
# Processing Record 37 of Set 8 | flinders
# Processing Record 38 of Set 8 | barawe
# City not found. Skipping...
# Processing Record 39 of Set 8 | shelburne
# Processing Record 40 of Set 8 | megion
# Processing Record 41 of Set 8 | mahajanga
# Processing Record 42 of Set 8 | tirano
# Processing Record 43 of Set 8 | paita
# Processing Record 44 of Set 8 | vila
# Processing Record 45 of Set 8 | bandarbeyla
# Processing Record 46 of Set 8 | coquimbo
# Processing Record 47 of Set 8 | phan rang
# City not found. Skipping...
# Processing Record 48 of Set 8 | roma
# Processing Record 49 of Set 8 | straumen
# Processing Record 50 of Set 8 | dolgoye
# Processing Record 1 of Set 9 | katherine
# Processing Record 2 of Set 9 | brae
# Processing Record 3 of Set 9 | sabha
# Processing Record 4 of Set 9 | datong
# Processing Record 5 of Set 9 | touros
# Processing Record 6 of Set 9 | sapele
# Processing Record 7 of Set 9 | blackwater
# Processing Record 8 of Set 9 | boyolangu
# Processing Record 9 of Set 9 | ransang
# Processing Record 10 of Set 9 | harper
# Processing Record 11 of Set 9 | grand gaube
# Processing Record 12 of Set 9 | buraydah
# Processing Record 13 of Set 9 | gobabis
# Processing Record 14 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 15 of Set 9 | isla aguada
# Processing Record 16 of Set 9 | vaitape
# Processing Record 17 of Set 9 | salinopolis
# Processing Record 18 of Set 9 | dunedin
# Processing Record 19 of Set 9 | zlobin
# Processing Record 20 of Set 9 | goundi
# Processing Record 21 of Set 9 | shebunino
# Processing Record 22 of Set 9 | semey
# Processing Record 23 of Set 9 | sangmelima
# Processing Record 24 of Set 9 | atambua
# Processing Record 25 of Set 9 | baherden
# Processing Record 26 of Set 9 | anqiu
# Processing Record 27 of Set 9 | rapid city
# Processing Record 28 of Set 9 | westport
# Processing Record 29 of Set 9 | jiazi
# Processing Record 30 of Set 9 | kharopon
# Processing Record 31 of Set 9 | ruidoso
# Processing Record 32 of Set 9 | seoul
# Processing Record 33 of Set 9 | acajutla
# Processing Record 34 of Set 9 | chumikan
# Processing Record 35 of Set 9 | stuttgart
# Processing Record 36 of Set 9 | bud
# Processing Record 37 of Set 9 | goderich
# Processing Record 38 of Set 9 | lucea
# Processing Record 39 of Set 9 | qasigiannguit
# Processing Record 40 of Set 9 | buariki
# City not found. Skipping...
# Processing Record 41 of Set 9 | impfondo
# Processing Record 42 of Set 9 | koster
# Processing Record 43 of Set 9 | corinto
# Processing Record 44 of Set 9 | akyab
# Processing Record 45 of Set 9 | kolvereid
# Processing Record 46 of Set 9 | high level
# Processing Record 47 of Set 9 | mustasaari
# Processing Record 48 of Set 9 | de aar
# Processing Record 49 of Set 9 | waipawa
# Processing Record 50 of Set 9 | otane
# Processing Record 1 of Set 10 | sao filipe
# Processing Record 2 of Set 10 | zhigansk
# Processing Record 3 of Set 10 | mentok
# City not found. Skipping...
# Processing Record 4 of Set 10 | tungkang
# City not found. Skipping...
# Processing Record 5 of Set 10 | kavaratti
# Processing Record 6 of Set 10 | bell ville
# Processing Record 7 of Set 10 | mount isa
# Processing Record 8 of Set 10 | tabialan
# City not found. Skipping...
# Processing Record 9 of Set 10 | coihueco
# Processing Record 10 of Set 10 | vedaranniyam
# City not found. Skipping...
# Processing Record 11 of Set 10 | nizhneudinsk
# Processing Record 12 of Set 10 | yuli
# Processing Record 13 of Set 10 | asau
# Processing Record 14 of Set 10 | rio gallegos
# Processing Record 15 of Set 10 | yeppoon
# Processing Record 16 of Set 10 | ijsselstein
# Processing Record 17 of Set 10 | kemijarvi
# Processing Record 18 of Set 10 | tazovskiy
# Processing Record 19 of Set 10 | vilhena
# Processing Record 20 of Set 10 | loandjili
# Processing Record 21 of Set 10 | macau
# Processing Record 22 of Set 10 | yerbogachen
# Processing Record 23 of Set 10 | kahului
# Processing Record 24 of Set 10 | henzada
# City not found. Skipping...
# Processing Record 25 of Set 10 | vannes
# Processing Record 26 of Set 10 | hvide sande
# Processing Record 27 of Set 10 | hays
# Processing Record 28 of Set 10 | nouakchott
# Processing Record 29 of Set 10 | mitsamiouli
# Processing Record 30 of Set 10 | ambilobe
# Processing Record 31 of Set 10 | kamaishi
# Processing Record 32 of Set 10 | miramar
# Processing Record 33 of Set 10 | port hedland
# Processing Record 34 of Set 10 | george town
# Processing Record 35 of Set 10 | lucapa
# Processing Record 36 of Set 10 | asosa
# Processing Record 37 of Set 10 | talnakh
# Processing Record 38 of Set 10 | vila velha
# Processing Record 39 of Set 10 | penarroya-pueblonuevo
# Processing Record 40 of Set 10 | lakes entrance
# Processing Record 41 of Set 10 | muzhi
# Processing Record 42 of Set 10 | nizhniy kuranakh
# Processing Record 43 of Set 10 | kaeo
# Processing Record 44 of Set 10 | vila franca do campo
# Processing Record 45 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 46 of Set 10 | pemangkat
# Processing Record 47 of Set 10 | kropotkin
# Processing Record 48 of Set 10 | la gaulette
# City not found. Skipping...
# Processing Record 49 of Set 10 | khour
# City not found. Skipping...
# Processing Record 50 of Set 10 | kysyl-syr
# Processing Record 1 of Set 11 | los llanos de aridane
# Processing Record 2 of Set 11 | kijang
# Processing Record 3 of Set 11 | laukaa
# Processing Record 4 of Set 11 | marienburg
# Processing Record 5 of Set 11 | calatayud
# Processing Record 6 of Set 11 | tabou
# Processing Record 7 of Set 11 | nampula
# Processing Record 8 of Set 11 | dehloran
# Processing Record 9 of Set 11 | sioux lookout
# Processing Record 10 of Set 11 | purpe
# Processing Record 11 of Set 11 | pochutla
# Processing Record 12 of Set 11 | tucumcari
# Processing Record 13 of Set 11 | samarai
# Processing Record 14 of Set 11 | olinda
# Processing Record 15 of Set 11 | senanga
# Processing Record 16 of Set 11 | lodja
# Processing Record 17 of Set 11 | tignere
# Processing Record 18 of Set 11 | zheshart
# Processing Record 19 of Set 11 | malwan
# City not found. Skipping...
# Processing Record 20 of Set 11 | gannan
# Processing Record 21 of Set 11 | shakawe
# Processing Record 22 of Set 11 | huanren
# Processing Record 23 of Set 11 | levittown
# Processing Record 24 of Set 11 | necochea
# Processing Record 25 of Set 11 | ambon
# Processing Record 26 of Set 11 | mbandaka
# Processing Record 27 of Set 11 | ust-nera
# Processing Record 28 of Set 11 | repnoye
# Processing Record 29 of Set 11 | wattegama
# Processing Record 30 of Set 11 | soe
# Processing Record 31 of Set 11 | noumea
# Processing Record 32 of Set 11 | mecca
# Processing Record 33 of Set 11 | ancud
# Processing Record 34 of Set 11 | fairbanks
# Processing Record 35 of Set 11 | ossora
# Processing Record 36 of Set 11 | nyurba
# Processing Record 37 of Set 11 | broome
# Processing Record 38 of Set 11 | san ramon
# Processing Record 39 of Set 11 | puerto narino
# Processing Record 40 of Set 11 | flekkefjord
# Processing Record 41 of Set 11 | atar
# Processing Record 42 of Set 11 | half moon bay
# Processing Record 43 of Set 11 | zaraza
# Processing Record 44 of Set 11 | axim
# Processing Record 45 of Set 11 | ibra
# Processing Record 46 of Set 11 | tochio
# Processing Record 47 of Set 11 | urut
# Processing Record 48 of Set 11 | pangai
# Processing Record 49 of Set 11 | kyabe
# Processing Record 50 of Set 11 | nioro
# Processing Record 1 of Set 12 | itigi
# Processing Record 2 of Set 12 | ornskoldsvik
# Processing Record 3 of Set 12 | bujumbura
# Processing Record 4 of Set 12 | sao gabriel da cachoeira
# Processing Record 5 of Set 12 | tutoia
# Processing Record 6 of Set 12 | codrington
# Processing Record 7 of Set 12 | rosarito
# Processing Record 8 of Set 12 | shitanjing
# Processing Record 9 of Set 12 | omutinskoye
# City not found. Skipping...
# Processing Record 10 of Set 12 | kieta
# Processing Record 11 of Set 12 | lanigan
# Processing Record 12 of Set 12 | guirang
# Processing Record 13 of Set 12 | salina cruz
# Processing Record 14 of Set 12 | enid
# Processing Record 15 of Set 12 | valdivia
# Processing Record 16 of Set 12 | ingham
# Processing Record 17 of Set 12 | makinsk
# Processing Record 18 of Set 12 | boende
# Processing Record 19 of Set 12 | kamenka
# Processing Record 20 of Set 12 | portland
# Processing Record 21 of Set 12 | usingen
# Processing Record 22 of Set 12 | siverek
# Processing Record 23 of Set 12 | ardistan
# City not found. Skipping...
# Processing Record 24 of Set 12 | egvekinot
# Processing Record 25 of Set 12 | saint anthony
# Processing Record 26 of Set 12 | jiddah
# City not found. Skipping...
# Processing Record 27 of Set 12 | luanda
# Processing Record 28 of Set 12 | kununurra
# Processing Record 29 of Set 12 | tahoua
# Processing Record 30 of Set 12 | bacolod
# Processing Record 31 of Set 12 | jining
# Processing Record 32 of Set 12 | mwense
# Processing Record 33 of Set 12 | lasa
# Processing Record 34 of Set 12 | kupang
# Processing Record 35 of Set 12 | yulara
# Processing Record 36 of Set 12 | woodward
# Processing Record 37 of Set 12 | clive
# Processing Record 38 of Set 12 | tessalit
# Processing Record 39 of Set 12 | labuhan
# Processing Record 40 of Set 12 | kontagora
# Processing Record 41 of Set 12 | xushan
# Processing Record 42 of Set 12 | bjala
# City not found. Skipping...
# Processing Record 43 of Set 12 | kadykchan
# City not found. Skipping...
# Processing Record 44 of Set 12 | payo
# Processing Record 45 of Set 12 | trairi
# Processing Record 46 of Set 12 | shimoda
# Processing Record 47 of Set 12 | saint-francois
# Processing Record 48 of Set 12 | mangrol
# Processing Record 49 of Set 12 | grand island
# Processing Record 50 of Set 12 | qui nhon
# Processing Record 1 of Set 13 | potsdam
# Processing Record 2 of Set 13 | cape coast
# Processing Record 3 of Set 13 | itoman
# Processing Record 4 of Set 13 | havoysund
# Processing Record 5 of Set 13 | dimitrovgrad
# Processing Record 6 of Set 13 | manavalakurichi
# Processing Record 7 of Set 13 | taree
# Processing Record 8 of Set 13 | rondonopolis
# Processing Record 9 of Set 13 | novopokrovka
# Processing Record 10 of Set 13 | bambari
# Processing Record 11 of Set 13 | solsvik
# City not found. Skipping...
# Processing Record 12 of Set 13 | sulurpeta
# City not found. Skipping...
# Processing Record 13 of Set 13 | kostino
# Processing Record 14 of Set 13 | tautira
# Processing Record 15 of Set 13 | geresk
# City not found. Skipping...
# Processing Record 16 of Set 13 | hualmay
# Processing Record 17 of Set 13 | mandera
# Processing Record 18 of Set 13 | saint george
# Processing Record 19 of Set 13 | ramanathapuram
# Processing Record 20 of Set 13 | umm jarr
# City not found. Skipping...
# Processing Record 21 of Set 13 | kungurtug
# Processing Record 22 of Set 13 | apatity
# Processing Record 23 of Set 13 | tiarei
# Processing Record 24 of Set 13 | pangnirtung
# Processing Record 25 of Set 13 | dalmatovo
# Processing Record 26 of Set 13 | kibray
# Processing Record 27 of Set 13 | ramgarh
# Processing Record 28 of Set 13 | idil
# Processing Record 29 of Set 13 | ruatoria
# City not found. Skipping...
# Processing Record 30 of Set 13 | irbeyskoye
# Processing Record 31 of Set 13 | balkanabat
# Processing Record 32 of Set 13 | kalmunai
# Processing Record 33 of Set 13 | iwade
# Processing Record 34 of Set 13 | minab
# Processing Record 35 of Set 13 | amapa
# Processing Record 36 of Set 13 | khromtau
# Processing Record 37 of Set 13 | venice
# Processing Record 38 of Set 13 | bloomsburg
# Processing Record 39 of Set 13 | magdagachi
# Processing Record 40 of Set 13 | luganville
# Processing Record 41 of Set 13 | gloversville
# Processing Record 42 of Set 13 | ghanzi
# Processing Record 43 of Set 13 | dargaville
# Processing Record 44 of Set 13 | usila
# City not found. Skipping...
# Processing Record 45 of Set 13 | suez
# Processing Record 46 of Set 13 | baracoa
# Processing Record 47 of Set 13 | krasnouralsk
# Processing Record 48 of Set 13 | zharkent
# Processing Record 49 of Set 13 | gotsu
# Processing Record 50 of Set 13 | adrar
# Processing Record 1 of Set 14 | saint-pierre
# Processing Record 2 of Set 14 | menongue
# Processing Record 3 of Set 14 | smidovich
# Processing Record 4 of Set 14 | devils lake
# Processing Record 5 of Set 14 | bajil
# Processing Record 6 of Set 14 | guajara-mirim
# City not found. Skipping...
# Processing Record 7 of Set 14 | kishanganj
# Processing Record 8 of Set 14 | remanso
# Processing Record 9 of Set 14 | nouadhibou
# Processing Record 10 of Set 14 | umzimvubu
# City not found. Skipping...
# Processing Record 11 of Set 14 | baker city
# Processing Record 12 of Set 14 | lorengau
# Processing Record 13 of Set 14 | ngukurr
# City not found. Skipping...
# Processing Record 14 of Set 14 | henderson
# Processing Record 15 of Set 14 | esmeraldas
# Processing Record 16 of Set 14 | nautla
# Processing Record 17 of Set 14 | visby
# Processing Record 18 of Set 14 | wewak
# Processing Record 19 of Set 14 | moulins
# Processing Record 20 of Set 14 | tura
# Processing Record 21 of Set 14 | chalette-sur-loing
# Processing Record 22 of Set 14 | baoro
# Processing Record 23 of Set 14 | sorland
# Processing Record 24 of Set 14 | kashan
# Processing Record 25 of Set 14 | iquique
# Processing Record 26 of Set 14 | tahta
# Processing Record 27 of Set 14 | touba
# Processing Record 28 of Set 14 | columbus
# Processing Record 29 of Set 14 | nueva loja
# Processing Record 30 of Set 14 | vanimo
# Processing Record 31 of Set 14 | safford
# Processing Record 32 of Set 14 | raudeberg
# Processing Record 33 of Set 14 | sao sebastiao
# Processing Record 34 of Set 14 | pulandian
# Processing Record 35 of Set 14 | hessisch lichtenau
# Processing Record 36 of Set 14 | ixtapa
# Processing Record 37 of Set 14 | eirunepe
# Processing Record 38 of Set 14 | bitung
# Processing Record 39 of Set 14 | guozhen
# Processing Record 40 of Set 14 | port hawkesbury
# Processing Record 41 of Set 14 | nurota
# Processing Record 42 of Set 14 | laguna
# Processing Record 43 of Set 14 | catumbela
# Processing Record 44 of Set 14 | west bay
# Processing Record 45 of Set 14 | poya
# Processing Record 46 of Set 14 | hanna
# Processing Record 47 of Set 14 | svetlyy
# Processing Record 48 of Set 14 | nyakahanga
# Processing Record 49 of Set 14 | voronovytsya
# Processing Record 50 of Set 14 | cochrane
# Processing Record 1 of Set 15 | sola
# Processing Record 2 of Set 15 | camacha
# Processing Record 3 of Set 15 | tomatlan
# Processing Record 4 of Set 15 | omboue
# Processing Record 5 of Set 15 | porto velho
# Processing Record 6 of Set 15 | araouane
# Processing Record 7 of Set 15 | fare
# Processing Record 8 of Set 15 | asayita
# City not found. Skipping...
# Processing Record 9 of Set 15 | wajir
# Processing Record 10 of Set 15 | ust-kuyga
# Processing Record 11 of Set 15 | khao yoi
# Processing Record 12 of Set 15 | suda
# Processing Record 13 of Set 15 | shaowu
# Processing Record 14 of Set 15 | berbera
# Processing Record 15 of Set 15 | marcona
# City not found. Skipping...
# Processing Record 16 of Set 15 | waitati
# Processing Record 17 of Set 15 | katsuura
# Processing Record 18 of Set 15 | beipiao
# Processing Record 19 of Set 15 | ukiah
# Processing Record 20 of Set 15 | watertown
# Processing Record 21 of Set 15 | pimenteiras
# Processing Record 22 of Set 15 | karratha
# Processing Record 23 of Set 15 | lethem
# Processing Record 24 of Set 15 | la macarena
# Processing Record 25 of Set 15 | bar harbor
# Processing Record 26 of Set 15 | murgab
# Processing Record 27 of Set 15 | maldonado
# Processing Record 28 of Set 15 | alta floresta
# Processing Record 29 of Set 15 | gwadar
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 670

# %%
#convert the list to a df
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Poum -20.2333  164.0167     76.23        91         100
# 1       Thompson  55.7435  -97.8558     53.60        30          20
# 2      Ilulissat  69.2167  -51.1000     33.80        86          90
# 3         Dikson  73.5069   80.5464      1.83        77          52
# 4  Berdigestyakh  62.0989  126.6992     33.01        99         100
#
#    Wind Speed Country                 Date Current Description
# 0       10.63      NC  2021-04-08 23:58:25          light rain
# 1        8.05      CA  2021-04-08 23:58:25          few clouds
# 2       10.36      GL  2021-04-08 23:58:25                snow
# 3       12.17      RU  2021-04-08 23:58:26       broken clouds
# 4        5.84      RU  2021-04-08 23:58:26          light snow

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity","Cloudiness", "Wind Speed","Current Description"]
city_data_df = city_data_df[new_column_order]

# %%
city_data_df
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0             Poum      NC -20.2333  164.0167     76.23        91         100
# 1         Thompson      CA  55.7435  -97.8558     53.60        30          20
# 2        Ilulissat      GL  69.2167  -51.1000     33.80        86          90
# 3           Dikson      RU  73.5069   80.5464      1.83        77          52
# 4    Berdigestyakh      RU  62.0989  126.6992     33.01        99         100
# ..             ...     ...      ...       ...       ...       ...         ...
# 665     Bar Harbor      US  44.3876  -68.2039     55.40        67          90
# 666         Murgab      TM  37.4966   61.9714     60.80        55          33
# 667      Maldonado      UY -34.6667  -54.9167     77.00        83           0
# 668  Alta Floresta      BR  -9.8756  -56.0861     78.80        89          40
# 669         Gwadar      PK  25.1216   62.3254     76.87        60           1
#
#      Wind Speed Current Description
# 0         10.63          light rain
# 1          8.05          few clouds
# 2         10.36                snow
# 3         12.17       broken clouds
# 4          5.84          light snow
# ..          ...                 ...
# 665        5.53     overcast clouds
# 666        4.61    scattered clouds
# 667        8.05       moderate rain
# 668        1.14    scattered clouds
# 669       10.33           clear sky
#
# [670 rows x 9 columns]

# %%
#create the output file (CSV).
output_data_file = "weather_database/WeatherPy_Database.csv"

#export the city_data into csv
city_data_df.to_csv(output_data_file, index_label="City_ID")
